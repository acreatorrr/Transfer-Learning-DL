# %% [markdown]
# <a href="https://colab.research.google.com/github/acreatorrr/Transfer-Learning-DL/blob/main/Transfer_Learning_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
from keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img

# %% [markdown]
# Dog Identification

# %%
dog_img_path = '/content/gdrive/MyDrive/Dog transfer learning.png'

# %%
dog_picture = load_img(r"/content/gdrive/MyDrive/Dog transfer learning.png")
dog_picture
# Out:
# <PIL.Image.Image image mode=RGB size=752x814 at 0x7F19FB8D1F10>

# %%
img = image.load_img(dog_img_path, target_size=(224, 224))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02099712', 'Labrador_retriever', 0.9718596), ('n02099601', 'golden_retriever', 0.020399036), ('n02088364', 'beagle', 0.000974427)]

# %% [markdown]
# Bird Identification

# %%
bird_img_path = "/content/gdrive/MyDrive/bird for transfer learning.png"

# %%
bird_picture = load_img(r"/content/gdrive/MyDrive/bird for transfer learning.png")
bird_picture
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=275x183 at 0x7F19FB7FA690>

# %%
img = image.load_img(bird_img_path, target_size=(224, 224))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n01795545', 'black_grouse', 0.4469362), ('n01824575', 'coucal', 0.17397068), ('n01616318', 'vulture', 0.062452417)]

# %% [markdown]
# 2Birds Identification

# %%
two_bird_img_path="/content/gdrive/MyDrive/2birds TL.jpg"

# %%
two_bird_picture = load_img(r"/content/gdrive/MyDrive/2birds TL.jpg")
two_bird_picture
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F19FB7B7150>

# %%
img = image.load_img(two_bird_img_path, target_size=(224, 224))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n01818515', 'macaw', 0.831415), ('n01820546', 'lorikeet', 0.0725468), ('n01531178', 'goldfinch', 0.03227902)]

# %% [markdown]
# Bike Identification

# %%
bike_img_path = load_img(r"/content/gdrive/MyDrive/bike TL.jpg")

# %%
bike_picture = load_img(r"/content/gdrive/MyDrive/bike TL.jpg")
bike_picture
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F19FB8D4250>

# %%
img = image.load_img("/content/gdrive/MyDrive/bike TL.jpg" ,target_size=(224, 224))

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03208938', 'disk_brake', 0.29608536), ('n03785016', 'moped', 0.1746394), ('n03127747', 'crash_helmet', 0.096411884)]
